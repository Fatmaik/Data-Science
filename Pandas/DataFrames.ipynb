# %%
import numpy as np
import pandas as pd

# %%
# Seed gera um numero aleatorio que permanessa com valor igual em qualquer PC
np.random.seed(101)

# %% [markdown]
# ### <br>Criar um DataFrame

# %%
df = pd.DataFrame(np.random.randn(4, 5), index = '1 2 3 4'.split(), columns = 'A B C D E'.split())

# %%
df
# Out:
#           A         B         C         D         E
# 1  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# 2  0.390528  0.166905  0.184502  0.807706  0.072960
# 3  0.638787  0.329646 -0.497104 -0.754070 -0.943406
# 4  0.484752 -0.116773  1.901755  0.238127  1.996652

# %% [markdown]
# ### <br>Inserir uma nova Coluna

# %%
df['sum_C_E'] = df['E'] + df['C']

# %%
df
# Out:
#           A         B         C         D         E   sum_C_E
# 1  0.302665  1.693723 -1.706086 -1.159119 -0.134841 -1.840927
# 2  0.390528  0.166905  0.184502  0.807706  0.072960  0.257462
# 3  0.638787  0.329646 -0.497104 -0.754070 -0.943406 -1.440510
# 4  0.484752 -0.116773  1.901755  0.238127  1.996652  3.898407

# %% [markdown]
# ### <br>Deletando Coluna

# %%
# 1- Modo UM
df = df.drop('sum_C_E', axis=1) # AXIS = 1 deleta a coluna, AXIS = 0 deleta linha
# Out:
#           A         B         C         D         E
# 1  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# 2  0.390528  0.166905  0.184502  0.807706  0.072960
# 3  0.638787  0.329646 -0.497104 -0.754070 -0.943406
# 4  0.484752 -0.116773  1.901755  0.238127  1.996652

# %%
# 2 - Modo Dois
df.drop('sum_C_E', axis=1, inplace=True)

# %%
df
# Out:
#           A         B         C         D         E
# 1  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# 2  0.390528  0.166905  0.184502  0.807706  0.072960
# 3  0.638787  0.329646 -0.497104 -0.754070 -0.943406
# 4  0.484752 -0.116773  1.901755  0.238127  1.996652

# %% [markdown]
# ### <br>Localizar Valor do DataFrame

# %% [markdown]
# Diferente do slice que existe no SERIES, o DF possui um metodo para encontrar valores expecíficos

# %% [markdown]
# <br>Ex: Método LOC()

# %%
# Seleciona o dado a través das chaves
df.loc['2', 'C']
# Out:
# 0.18450185928224264

# %% [markdown]
# <br>Ex: Método iloc()

# %%
# Seleciona os dados através de seus elementos, semelhante ao slice do Series
df.iloc[1:4, 2:]
# Out:
#           C         D         E
# 2  0.184502  0.807706  0.072960
# 3 -0.497104 -0.754070 -0.943406
# 4  1.901755  0.238127  1.996652

# %% [markdown]
# ### <br>Seleção Condicional

# %%
df > 0
# Out:
#       A      B      C      D      E   ids
# 1  True   True  False  False  False  True
# 2  True   True   True   True   True  True
# 3  True   True  False  False  False  True
# 4  True  False   True   True   True  True

# %% [markdown]
# <br>

# %%
df[df['A'] > 0]
# Out:
#           A         B         C         D         E     ids
# 1  0.302665  1.693723 -1.706086 -1.159119 -0.134841      UM
# 2  0.390528  0.166905  0.184502  0.807706  0.072960    DOIS
# 3  0.638787  0.329646 -0.497104 -0.754070 -0.943406    TRES
# 4  0.484752 -0.116773  1.901755  0.238127  1.996652  QUATRO

# %% [markdown]
# <br>

# %%
# Para usar os operadores (and ou or), usa-se (& ou |)
# Neste exemplo pagamos somente os valores da coluna "B" que são maiores que 0,
# Porem o valor da linha precisa ser tambẽm maior que 0 na coluna 'C"
df[(df['C']>0) & (df['B']>0)]['B']
# Out:
# 2    0.166905
# Name: B, dtype: float64

# %% [markdown]
# <br>

# %%
df[df['B']>0]['A']
# Out:
# 1    0.302665
# 2    0.390528
# 3    0.638787
# Name: A, dtype: float64

# %% [markdown]
# <br>

# %% [markdown]
# ### <br><br>Alterando/Resetando o Index

# %%
df
# Out:
#           A         B         C         D         E
# 1  0.302665  1.693723 -1.706086 -1.159119 -0.134841
# 2  0.390528  0.166905  0.184502  0.807706  0.072960
# 3  0.638787  0.329646 -0.497104 -0.754070 -0.943406
# 4  0.484752 -0.116773  1.901755  0.238127  1.996652

# %%
# Primeiramento é necessário a criação de uma nova coluna com seus devidos valores
df['ids'] = ['UM', 'DOIS', 'TRES', 'QUATRO']

# %%
# Depois de feita a nova coluna, é possivel a tornar como o novo index
df.set_index('ids')
# Out:
#                A         B         C         D         E
# ids
# UM      0.302665  1.693723 -1.706086 -1.159119 -0.134841
# DOIS    0.390528  0.166905  0.184502  0.807706  0.072960
# TRES    0.638787  0.329646 -0.497104 -0.754070 -0.943406
# QUATRO  0.484752 -0.116773  1.901755  0.238127  1.996652

# %% [markdown]
# ### <br><br>Criação de DataFrame atraves de arquivo CSV

# %%
# descobrir qual é o separador
# !head DATASETS/Consulta_de_compras_diretas.csv
# Out:
# Exportado em: 27/06/2018;;;;;;;;;Transparência Fly;
# Camboriú - SC;;;;;;;;;;
# Todas as entidades do município;;;;;;;;;;
# Consulta de compras diretas;;;;;Última atualização: 27/06/2018 22:25:08;;;;;
# Filtros utilizados para elaboração da consulta: Entidade: Todas | Ano: 2018 | Mês: Junho | Centro de custos: Todos | Tipo de compra: Todos;;;;;;;;;;
# Compra;Data da compra;Objeto;Centro de custos;Fornecedor;;Valor (R$);Justificativa;Tipo de compra;;Anulação / Data
# 236 - 2018;25/06/2018;SERVIÇO PARA A MANUTENÇÃO DE EQUIPAMENTO LAVAJATO E ASPIRADOR  DE PÓ UTILIZADO NA LAVAÇÃO E LIMPEZA DAS VIATURAS DA 1ª CIA DE PM DE CAMBORIU.;SECRETARIA DE ADMINISTRAÇÃO;IEDA TEREZINHA FERREIRADE SOUZA VEQUI - ME.;;360,00;;Compra Comum;;
# 235 - 2018;25/06/2018;AQUISIÇÃO DE FITAS DE ISOLAMENTO DE ÁREA PARA O QUARTEL DO CORPO DE BOMBEIROS MILITAR DE CAMBORIU.;SECRETARIA DE ADMINISTRAÇÃO;RIC INDUSTRIA E COMERCIO DE ETIQUETAS EIRELI - EPP;;1.125,00;;Compra Comum;;
# ...

# %% [markdown]
# <br>

# %%
# Lendo arquivo csv
dataset = pd.read_csv("DATASETS/Consulta_de_compras_diretas.csv", sep=';')

# %%
dataset
# Out:
#                               Exportado em: 27/06/2018      Unnamed: 1  \
# 0                                        Camboriú - SC             NaN
# 1                      Todas as entidades do município             NaN
# 2                          Consulta de compras diretas             NaN
# 3    Filtros utilizados para elaboração da consulta...             NaN
# 4                                               Compra  Data da compra
# 5                                           236 - 2018      25/06/2018
# 6                                           235 - 2018      25/06/2018
# 7                                           234 - 2018      22/06/2018
# 8                                           233 - 2018      19/06/2018
# 9                                           232 - 2018      14/06/2018
# 10                                          231 - 2018      14/06/2018
# 11                                          230 - 2018      14/06/2018
# ...

# %% [markdown]
# <br>

# %% [markdown]
# <br> Deletando as linhas inconsistentes

# %%
dataset.drop([0, 1, 2, 3], inplace = True)

# %%
dataset
# Out:
#     Exportado em: 27/06/2018      Unnamed: 1  \
# 4                     Compra  Data da compra
# 5                 236 - 2018      25/06/2018
# 6                 235 - 2018      25/06/2018
# 7                 234 - 2018      22/06/2018
# 8                 233 - 2018      19/06/2018
# 9                 232 - 2018      14/06/2018
# 10                231 - 2018      14/06/2018
# 11                230 - 2018      14/06/2018
# 12                229 - 2018      14/06/2018
# 13                228 - 2018      14/06/2018
# 14                227 - 2018      07/06/2018
# 15                226 - 2018      30/05/2018
# 16                225 - 2018      04/06/2018
# 17                224 - 2018      30/05/2018
# 18                223 - 2018      30/05/2018
# 19                222 - 2018      28/05/2018
# 20                221 - 2018      23/05/2018
# 21                220 - 2018      23/05/2018
# 22                219 - 2018      23/05/2018
# 23                218 - 2018      23/05/2018
# ...

# %% [markdown]
# <br> Deletando as colunas inconsistentes

# %%
dataset.drop(['Unnamed: 5', 'Unnamed: 7', 'Transparência Fly', 'Unnamed: 8', 'Unnamed: 10'], axis = 1, inplace = True)
dataset
# Out:
#     Exportado em: 27/06/2018      Unnamed: 1  \
# 4                     Compra  Data da compra
# 5                 236 - 2018      25/06/2018
# 6                 235 - 2018      25/06/2018
# 7                 234 - 2018      22/06/2018
# 8                 233 - 2018      19/06/2018
# 9                 232 - 2018      14/06/2018
# 10                231 - 2018      14/06/2018
# 11                230 - 2018      14/06/2018
# 12                229 - 2018      14/06/2018
# 13                228 - 2018      14/06/2018
# 14                227 - 2018      07/06/2018
# 15                226 - 2018      30/05/2018
# 16                225 - 2018      04/06/2018
# 17                224 - 2018      30/05/2018
# 18                223 - 2018      30/05/2018
# 19                222 - 2018      28/05/2018
# 20                221 - 2018      23/05/2018
# 21                220 - 2018      23/05/2018
# 22                219 - 2018      23/05/2018
# 23                218 - 2018      23/05/2018
# ...

# %% [markdown]
# <br> Alterando o Cabeçalho do Dataset

# %%
dataset.columns = ['COMPRA', 'DATA DA COMPRA', 'OBJETO', 'CENTRO DE CUSTOS', 'FORNECEDOR', 'VALOR (R$)']

# %%
dataset
# Out:
#          COMPRA  DATA DA COMPRA  \
# 4        Compra  Data da compra
# 5    236 - 2018      25/06/2018
# 6    235 - 2018      25/06/2018
# 7    234 - 2018      22/06/2018
# 8    233 - 2018      19/06/2018
# 9    232 - 2018      14/06/2018
# 10   231 - 2018      14/06/2018
# 11   230 - 2018      14/06/2018
# 12   229 - 2018      14/06/2018
# 13   228 - 2018      14/06/2018
# 14   227 - 2018      07/06/2018
# 15   226 - 2018      30/05/2018
# 16   225 - 2018      04/06/2018
# 17   224 - 2018      30/05/2018
# 18   223 - 2018      30/05/2018
# 19   222 - 2018      28/05/2018
# 20   221 - 2018      23/05/2018
# 21   220 - 2018      23/05/2018
# 22   219 - 2018      23/05/2018
# 23   218 - 2018      23/05/2018
# 24   217 - 2018      23/05/2018
# 25   216 - 2018      17/05/2018
# 26   215 - 2018      17/05/2018
# 27   214 - 2018      17/05/2018
# 28   213 - 2018      15/05/2018
# 29   212 - 2018      14/05/2018
# 30   211 - 2018      14/05/2018
# 31   210 - 2018      14/05/2018
# ...

# %% [markdown]
# <br>Resetar o Index

# %%
dataset.drop([4], inplace=True)

# %%
dataset
# Out:
#          COMPRA DATA DA COMPRA  \
# 5    236 - 2018     25/06/2018
# 6    235 - 2018     25/06/2018
# 7    234 - 2018     22/06/2018
# 8    233 - 2018     19/06/2018
# 9    232 - 2018     14/06/2018
# 10   231 - 2018     14/06/2018
# 11   230 - 2018     14/06/2018
# 12   229 - 2018     14/06/2018
# 13   228 - 2018     14/06/2018
# 14   227 - 2018     07/06/2018
# 15   226 - 2018     30/05/2018
# 16   225 - 2018     04/06/2018
# 17   224 - 2018     30/05/2018
# 18   223 - 2018     30/05/2018
# 19   222 - 2018     28/05/2018
# 20   221 - 2018     23/05/2018
# 21   220 - 2018     23/05/2018
# 22   219 - 2018     23/05/2018
# 23   218 - 2018     23/05/2018
# 24   217 - 2018     23/05/2018
# 25   216 - 2018     17/05/2018
# 26   215 - 2018     17/05/2018
# 27   214 - 2018     17/05/2018
# 28   213 - 2018     15/05/2018
# 29   212 - 2018     14/05/2018
# 30   211 - 2018     14/05/2018
# 31   210 - 2018     14/05/2018
# 32   209 - 2018     14/05/2018
# 33   208 - 2018     14/05/2018
# ...

# %%
# Criação de Uma lista que contera todos os elementos do index.
new_index = []

# Percorrendo todos os Elementos do Dataset
for i in dataset.index:
    new_index.append(i - 4) # O array recebe os elementos - 4, devido o inicio do index estar com valor = 5
    
# Criação da nova coluna que servirá como o index
dataset['New Index'] = new_index

# Alterando o index do Dataset para a nova coluna contendo um index desde o numero 1
dataset.set_index('New Index')
# Out:
#                COMPRA DATA DA COMPRA  \
# New Index
# 1          236 - 2018     25/06/2018
# 2          235 - 2018     25/06/2018
# 3          234 - 2018     22/06/2018
# 4          233 - 2018     19/06/2018
# 5          232 - 2018     14/06/2018
# 6          231 - 2018     14/06/2018
# 7          230 - 2018     14/06/2018
# 8          229 - 2018     14/06/2018
# 9          228 - 2018     14/06/2018
# 10         227 - 2018     07/06/2018
# 11         226 - 2018     30/05/2018
# 12         225 - 2018     04/06/2018
# 13         224 - 2018     30/05/2018
# 14         223 - 2018     30/05/2018
# 15         222 - 2018     28/05/2018
# 16         221 - 2018     23/05/2018
# 17         220 - 2018     23/05/2018
# 18         219 - 2018     23/05/2018
# 19         218 - 2018     23/05/2018
# 20         217 - 2018     23/05/2018
# 21         216 - 2018     17/05/2018
# 22         215 - 2018     17/05/2018
# 23         214 - 2018     17/05/2018
# 24         213 - 2018     15/05/2018
# ...

# %% [markdown]
# ### <br><br>APLICANDO FUNÇÕES

# %%
# Aplicando uma função que substitui a por b
dataset.apply(lambda x: x.replace('a', 'b'))
# Out:
#                               Exportado em: 27/06/2018      Unnamed: 1  \
# 0                                        Camboriú - SC             NaN
# 1                      Todas as entidades do município             NaN
# 2                          Consulta de compras diretas             NaN
# 3    Filtros utilizados para elaboração da consulta...             NaN
# 4                                               Compra  Data da compra
# 5                                           236 - 2018      25/06/2018
# 6                                           235 - 2018      25/06/2018
# 7                                           234 - 2018      22/06/2018
# 8                                           233 - 2018      19/06/2018
# 9                                           232 - 2018      14/06/2018
# 10                                          231 - 2018      14/06/2018
# 11                                          230 - 2018      14/06/2018
# ...

# %% [markdown]
# ### <br><br>APLICANDO FUNÇÕES

# %%
d = {'A':[1, 2, np.nan], 'B':[5, np.nan, np.nan], 'C':[1, 2, 3]}

# %%
df = pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
# Aplicando uma função que substitui a por b
df.apply(lambda x: x.replace('a', 'b'))
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %% [markdown]
# <br>

# %%
# Preencher valores null, com valores padrao = 0
df.tail()
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %% [markdown]
# <br>

# %%
# Removendo lacunas que estão inconsistentes
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
# Removendo somente linhas com 2 elementos iguais a NaN
df.dropna(thresh=2)
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2

# %%
# Substituir os calores faltantes, pelos valores anteriores
df.fillna(method='ffill')
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  5.0  2
# 2  2.0  5.0  3

# %%
# Em caso de nao querer deletar valores faltantes, e substituilos pela media
dataset['VALOR R$'].fillna(dataset{'VALOR R$'}.mean(), inplace=True)

# %% [markdown]
# <br>

# %%
# Converter totos os numeros FLOAT para INT
dataset['nome_da_coluna_que_pretende_altera'] = dataset['nome_da_coluna_que_pretende_altera'].map(lambda x: int(x))

# %% [markdown]
# <br>

# %%
# Ordenando valores

# ORDENANDO EM ORDEM CRESCENTE
dataset.sort_values()

# ORDENANDO EM ORDEM DECRESCENTE
dataset.sort_values(ascenting=False)

# %% [markdown]
# <br>
